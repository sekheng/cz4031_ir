# %%
import pandas as pd
import pysolr
import os

# %%
# establish connection with the core
core_path = "http://localhost:8983/solr/stock_project_core"
solr = pysolr.Solr(core_path, always_commit=True)

# %% [markdown]
# # Remove all indexes from the core

# %%
# remove all index
solr.delete(q='*:*')
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<response>\n\n<lst name="responseHeader">\n  <int name="status">0</int>\n  <int name="QTime">71</int>\n</lst>\n</response>\n'

# %% [markdown]
# # Index data from csv

# %%
# load csv data (labelling version)
csv_path = "IR_New_Testing_Data - Tesing_Data.csv"

csv_data = pd.read_csv(csv_path, dtype={'tweet_id': 'int64'}, float_precision='round_trip')
csv_data['tweet_id'] = csv_data['tweet_id'].astype(str)
csv_data.head(5)
# Out:
#   ticker_symbol                  post_date             tweet_id  \
# 0          AAPL  2023-01-01 22:23:31+00:00  1609676719925137408
# 1          AAPL  2023-01-01 21:04:45+00:00  1609656899674284032
# 2          AAPL  2023-01-01 20:44:51+00:00  1609651892447023104
# 3          AAPL  2023-01-01 19:45:30+00:00  1609636954454343680
# 4          AAPL  2023-01-01 19:00:00+00:00  1609625505287790592
#
#            writer                                               body  \
# 0    David_Tracey  Things are going to get very interesting but w...
# 1  ASTS_Investors  Happy New Year SpaceMob! \n\nLet's hope 2023 w...
# 2        BigCheds  $AAPL Apple weekly chart - hammer candle with ...
# 3    ThetaWarrior        $AAPL Yearly -26.8% https://t.co/SewErQmOPE
# 4     TrendSpider  Looking for shorts into the new year? 📉\n\nThi...
#
#    like_num  comment_num  retweet_num  tweet_activity  url_cnt emoticons  \
# 0        27            1            2              30        2        []
# 1        64            0            3              67        1        []
# 2       104            9            5             118        1        []
# 3        80           10           10             100        1        []
# 4        28            4            4              36        1        []
#
#              emojis  emo_cnt  word_count  \
# 0                {}        0          11
# 1  {'🚀': 1, '🤠': 1}        2          21
# 2                {}        0          10
# 3                {}        0           4
# 4          {'📉': 1}        1          23
#
#                                           clean_text  subjectivity  sentiment  \
# 0  thing go get interest q1 forecast updat aapl r...             0        0.0
# 1  happi new year spacemob let hope 2023 year blu...             1        1.0
# 2  aapl appl weekli chart hammer candl spring jun...             0        0.0
# 3                                    aapl yearli 268             0        0.0
# 4  look short new year weekli triangl breakdown s...             1        1.0
#
#    moderator                            clean_text_no_stem_user
# 0        NaN  Things going get interesting My Q1 forecast So...
# 1        NaN  Happy New Year SpaceMob Lets hope 2023 year Bl...
# 2        NaN  AAPL Apple weekly chart hammer candle spring J...
# 3        NaN                                    AAPL Yearly 268
# 4        NaN  Looking shorts new year This weekly triangle b...

# %%
# extract csv data to be indexed
extracted_data = []
for index, row in csv_data.iterrows():
    extracted_data.append({"id": row["tweet_id"],
                           "company": row["ticker_symbol"],
                           "post_date": row["post_date"],
                            "author": row["writer"], 
                            "raw_text": row["body"], 
                            "like_num": row["like_num"],
                            "comment_num": row["comment_num"], 
                            "retweet_num": row["retweet_num"], 
                            "tweet_activity": row["tweet_activity"],
                            "clean_text": row["clean_text_no_stem_user"],
                            "subjectivity": row["subjectivity"], 
                            "sentiment": row["sentiment"]})

# %%
# define company names
ticker_symbol_to_name_mapping = {"AAPL": "apple",
                                "AMZN": "amazon",
                                "GOOGL": "google",
                                "MSFT": "Microsoft",
                                "TSLA": "Tesla"}

for i in range(len(extracted_data)):
    extracted_data[i]["company"] = ticker_symbol_to_name_mapping[extracted_data[i]["company"]]

# %%
# inspect data before indexing
extracted_data
# Out:
# [{'id': '1609676719925137408',
#   'company': 'apple',
#   'post_date': '2023-01-01 22:23:31+00:00',
#   'author': 'David_Tracey',
#   'raw_text': 'Things are going to get very interesting but when...?\nMy Q1 forecast below...\n\nSome updates here on $AAPL too as requested.\n\nhttps://t.co/dU1FcS22JP https://t.co/x8RhRPXHhD',
#   'like_num': 27,
#   'comment_num': 1,
#   'retweet_num': 2,
#   'tweet_activity': 30,
#   'clean_text': 'Things going get interesting My Q1 forecast Some updates AAPL requested',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609656899674284032',
#   'company': 'apple',
#   'post_date': '2023-01-01 21:04:45+00:00',
#   'author': 'ASTS_Investors',
#   'raw_text': "Happy New Year SpaceMob! \n\nLet's hope 2023 will be the year of #BlueWalker3 and $ASTS 🚀🤠\n\n#Space5G #5G $GSAT $T $AMT $TMUS $AAPL $IRDM #SpaceX $VOD https://t.co/cefLRpuvEl",
#   'like_num': 64,
#   'comment_num': 0,
#   'retweet_num': 3,
#   'tweet_activity': 67,
#   'clean_text': 'Happy New Year SpaceMob Lets hope 2023 year BlueWalker3 ASTS Space5G 5G GSAT T AMT TMUS AAPL IRDM SpaceX VOD',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609651892447023104',
#   'company': 'apple',
#   'post_date': '2023-01-01 20:44:51+00:00',
#   'author': 'BigCheds',
#   'raw_text': '$AAPL Apple weekly chart - hammer candle with spring from June lows https://t.co/5UTAgINmn2',
#   'like_num': 104,
#   'comment_num': 9,
#   'retweet_num': 5,
#   'tweet_activity': 118,
#   'clean_text': 'AAPL Apple weekly chart hammer candle spring June lows',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609636954454343680',
#   'company': 'apple',
#   'post_date': '2023-01-01 19:45:30+00:00',
#   'author': 'ThetaWarrior',
#   'raw_text': '$AAPL Yearly -26.8% https://t.co/SewErQmOPE',
#   'like_num': 80,
#   'comment_num': 10,
#   'retweet_num': 10,
#   'tweet_activity': 100,
#   'clean_text': 'AAPL Yearly 268',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609625505287790592',
#   'company': 'apple',
#   'post_date': '2023-01-01 19:00:00+00:00',
#   'author': 'TrendSpider',
#   'raw_text': 'Looking for shorts into the new year? 📉\n\nThis weekly triangle breakdown scan is a great way to generate some potential candidates in seconds!\n\n$AAPL $DLTR $CMG $DG $MOS $CF $ALB\n\nhttps://t.co/iceKYDRwye',
#   'like_num': 28,
#   'comment_num': 4,
#   'retweet_num': 4,
#   'tweet_activity': 36,
#   'clean_text': 'Looking shorts new year This weekly triangle breakdown scan great way generate potential candidates seconds AAPL DLTR CMG DG MOS CF ALB',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609585344948887552',
#   'company': 'apple',
#   'post_date': '2023-01-01 16:20:25+00:00',
#   'author': 'lord_fed',
#   'raw_text': 'Don’t really see what is holding $AAPL up @ 20x P/E\n\nCould see 107-113 in 2023. Can’t imagine much further down.',
#   'like_num': 149,
#   'comment_num': 36,
#   'retweet_num': 13,
#   'tweet_activity': 198,
#   'clean_text': 'Dont really see holding AAPL 20x PE Could see 107113 2023 Cant imagine much',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1609552780863369216',
#   'company': 'apple',
#   'post_date': '2023-01-01 14:11:01+00:00',
#   'author': 'Mr_Derivatives',
#   'raw_text': "$AAPL A lot of ppl might be surprised if I said in 2023 Apple could see $95. But then again a lot of ppl didn't think TSLA would have crashed that hard either!\n\nWe got a nice rounding top formation, and a huge gap fill at $95, which will still be well above pre-covid highs!\n\nFWIW https://t.co/8n37VOPyUu",
#   'like_num': 519,
#   'comment_num': 46,
#   'retweet_num': 44,
#   'tweet_activity': 609,
#   'clean_text': 'AAPL A lot ppl might surprised I said 2023 Apple could see 95 But lot ppl didnt think TSLA would crashed hard either We got nice rounding top formation huge gap fill 95 still well precovid highs FWIW',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609542582652084224',
#   'company': 'apple',
#   'post_date': '2023-01-01 13:30:30+00:00',
#   'author': 'ProblemSniper',
#   'raw_text': '📈 $AAPL Break of a trendline support on the weekly while the RSI and MACD are in inclined bearish with growing momentum and some bear positioning on it into the earnings cycle (Feb Positions). PT: 115 https://t.co/pkyYXpnLAK',
#   'like_num': 105,
#   'comment_num': 3,
#   'retweet_num': 8,
#   'tweet_activity': 116,
#   'clean_text': 'AAPL Break trendline support weekly RSI MACD inclined bearish growing momentum bear positioning earnings cycle Feb Positions PT 115',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609407163671400448',
#   'company': 'apple',
#   'post_date': '2023-01-01 04:32:23+00:00',
#   'author': 'The_AI_Investor',
#   'raw_text': 'Apple iphone market share peaked in H1 2009 and then falling, the stock should fall too, right? \n\nBut no, $AAPL was up 10x in the next 6 years from 2009 to 2015 https://t.co/vE04xsvtiM',
#   'like_num': 66,
#   'comment_num': 2,
#   'retweet_num': 4,
#   'tweet_activity': 72,
#   'clean_text': 'Apple iphone market share peaked H1 2009 falling stock fall right But AAPL 10x next 6 years 2009 2015',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609341872639512576',
#   'company': 'apple',
#   'post_date': '2023-01-01 00:12:57+00:00',
#   'author': 'NeelyTamminga',
#   'raw_text': 'FinTwit: $AAPL 📈📉 ?\nMe: mmmm 🍎🥧 https://t.co/fRUXuAlVD0',
#   'like_num': 52,
#   'comment_num': 13,
#   'retweet_num': 0,
#   'tweet_activity': 65,
#   'clean_text': 'FinTwit AAPL Me mmmm',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610040852876857344',
#   'company': 'apple',
#   'post_date': '2023-01-02 22:30:27+00:00',
#   'author': 'korinek_trades',
#   'raw_text': '$AAPL has met my long term target \n\nSatisfying A=C and testing the long term TL support level\n\nThe sub waves are corrective and the triangle suggests that this has been a constructive retracement \n\nCircled area holds, 160–&gt;180+ can trade again IMO\n\nVery important spot here https://t.co/vSPR0thPEm',
#   'like_num': 29,
#   'comment_num': 1,
#   'retweet_num': 8,
#   'tweet_activity': 38,
#   'clean_text': 'AAPL met long term target Satisfying AC testing long term TL support level The sub waves corrective triangle suggests constructive retracement Circled area holds 160gt180 trade IMO Very important spot',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610036971723948032',
#   'company': 'apple',
#   'post_date': '2023-01-02 22:15:01+00:00',
#   'author': 'BStew_ChArTs',
#   'raw_text': '$AAPL 🍎\n\nDaily and Weekly charts:\n\nWhat’s your thoughts? Bullish or Bearish?\n\nThere is a lot of support around this current area. \n\nIF AAPL breaks $105 area in 2023 there isn’t much support until around $82\n\nWill be Tech Giant maintain its #1 position? https://t.co/FOyLtSXxop',
#   'like_num': 40,
#   'comment_num': 6,
#   'retweet_num': 6,
#   'tweet_activity': 52,
#   'clean_text': 'AAPL Daily Weekly charts Whats thoughts Bullish Bearish There lot support around current area IF AAPL breaks 105 area 2023 isnt much support around 82 Will Tech Giant maintain 1 position',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610027687300718592',
#   'company': 'apple',
#   'post_date': '2023-01-02 21:38:08+00:00',
#   'author': 'JReam425',
#   'raw_text': "$AAPL Found some buyers off of $125. If you can't hold this level I am watching for move lower to $116, $107 https://t.co/QEGd9U1nxn",
#   'like_num': 22,
#   'comment_num': 6,
#   'retweet_num': 3,
#   'tweet_activity': 31,
#   'clean_text': 'AAPL Found buyers 125 If cant hold level I watching move lower 116 107',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610019650930098176',
#   'company': 'apple',
#   'post_date': '2023-01-02 21:06:12+00:00',
#   'author': 'BomsteinRick',
#   'raw_text': 'Well no one could have predicted this\n\nThank goodness everyone was already so bearish \n\n$aapl',
#   'like_num': 52,
#   'comment_num': 2,
#   'retweet_num': 4,
#   'tweet_activity': 58,
#   'clean_text': 'Well one could predicted Thank goodness everyone already bearish aapl',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610001379745206272',
#   'company': 'apple',
#   'post_date': '2023-01-02 19:53:35+00:00',
#   'author': 'Lorenzo51946078',
#   'raw_text': '@FinanceLancelot Over 4 mil on puts for $AAPL on Friday for February expiration at $115 strike. Someone knows something',
#   'like_num': 20,
#   'comment_num': 3,
#   'retweet_num': 2,
#   'tweet_activity': 25,
#   'clean_text': 'FinanceLancelot Over 4 mil puts AAPL Friday February expiration 115 strike Someone knows something',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1609989426675060736',
#   'company': 'apple',
#   'post_date': '2023-01-02 19:06:06+00:00',
#   'author': 'sttbreakingnews',
#   'raw_text': 'In response to weak demand, Apple $AAPL is cutting Q1 orders for AirPods, Apple Watch, MacBooks - Nikkei #apple #Airpods #MacBook',
#   'like_num': 39,
#   'comment_num': 3,
#   'retweet_num': 12,
#   'tweet_activity': 54,
#   'clean_text': 'In response weak demand Apple AAPL cutting Q1 orders AirPods Apple Watch MacBooks Nikkei apple Airpods MacBook',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1609980518736580608',
#   'company': 'apple',
#   'post_date': '2023-01-02 18:30:42+00:00',
#   'author': 'DividendDandy',
#   'raw_text': 'If you take $AAPL out of the equation $QQQ prob looks a lot worse',
#   'like_num': 19,
#   'comment_num': 6,
#   'retweet_num': 2,
#   'tweet_activity': 27,
#   'clean_text': 'If take AAPL equation QQQ prob looks lot worse',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1609972861925564416',
#   'company': 'apple',
#   'post_date': '2023-01-02 18:00:16+00:00',
#   'author': 'TheShortBear',
#   'raw_text': '$AAPL seems increasingly likely to put pressure on the markets. \n\n•Breakdown \n•No structure until -~20%\n•Put flow\n•News flow \n\nBREAKING:\n\nIn response to weak demand, Apple cutting Q1 orders for AirPods, Apple Watch, MacBooks - Nikkei',
#   'like_num': 88,
#   'comment_num': 6,
#   'retweet_num': 8,
#   'tweet_activity': 102,
#   'clean_text': 'AAPL seems increasingly likely put pressure markets Breakdown No structure 20 Put flow News flow BREAKING In response weak demand Apple cutting Q1 orders AirPods Apple Watch MacBooks Nikkei',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1609969363196731392',
#   'company': 'apple',
#   'post_date': '2023-01-02 17:46:22+00:00',
#   'author': 'daarkmaagician',
#   'raw_text': 'All those 🍎 $AAPL puts make sense now',
#   'like_num': 35,
#   'comment_num': 6,
#   'retweet_num': 1,
#   'tweet_activity': 42,
#   'clean_text': 'All AAPL puts make sense',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1609961083925843968',
#   'company': 'apple',
#   'post_date': '2023-01-02 17:13:28+00:00',
#   'author': 'MomAngtrades',
#   'raw_text': 'Wall Street also expects $AAPL to deliver 2 trillion iPhones. Anything less is unacceptable',
#   'like_num': 43,
#   'comment_num': 8,
#   'retweet_num': 3,
#   'tweet_activity': 54,
#   'clean_text': 'Wall Street also expects AAPL deliver 2 trillion iPhones Anything less unacceptable',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1609951807442411520',
#   'company': 'apple',
#   'post_date': '2023-01-02 16:36:37+00:00',
#   'author': 'InvestRepeat',
#   'raw_text': 'BREAKING: Apple hikes battery service charge from Mar 1, 2023.\n\nFor iPhone 13 &amp; older iPhones, replacement price changed from $69 to $89 (29% increase).\n\niPhones with home button battery, replacement will cost $69 instead of $49 (41% increase)\n\n$AAPL #Apple',
#   'like_num': 21,
#   'comment_num': 4,
#   'retweet_num': 1,
#   'tweet_activity': 26,
#   'clean_text': 'BREAKING Apple hikes battery service charge Mar 1 2023 For iPhone 13 amp older iPhones replacement price changed 69 89 29 increase iPhones home button battery replacement cost 69 instead 49 41 increase AAPL Apple',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609938537742467072',
#   'company': 'apple',
#   'post_date': '2023-01-02 15:43:53+00:00',
#   'author': 'SnipeTrades',
#   'raw_text': 'WEEKLY WATCHLIST: 1/2 - 1/6 \n\nChart of the week: $META\n\nUpside Momentum Watch:\n$META $JPM \n\nDownside Momentum Watch:\n$AAPL $AMD $MRNA https://t.co/Ked0ZXQIs5',
#   'like_num': 42,
#   'comment_num': 3,
#   'retweet_num': 3,
#   'tweet_activity': 48,
#   'clean_text': 'WEEKLY WATCHLIST 12 16 Chart week META Upside Momentum Watch META JPM Downside Momentum Watch AAPL AMD MRNA',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1609926528002834432',
#   'company': 'apple',
#   'post_date': '2023-01-02 14:56:09+00:00',
#   'author': 'BusinessFamous',
#   'raw_text': 'STOCKS BERKSHIRE BOUGHT IN 2022:\n\nOccidental Petroleum $OXY\nChevron $CVX\nHP $HPQ\nParamount $PARA\nTaiwan Semiconductor $TSM\nCitigroup $C\nActivision $ATVI\nAlly $ALLY\nCelanese $CE\nApple $AAPL\nLouisiana-Pacific $LPX\nFloor &amp; Décor $FND\nMcKesson $MCK\nRH $RH\nMarkel $MKL\nJefferies $JEF https://t.co/uHzQDTKaFi',
#   'like_num': 38,
#   'comment_num': 6,
#   'retweet_num': 9,
#   'tweet_activity': 53,
#   'clean_text': 'STOCKS BERKSHIRE BOUGHT IN 2022 Occidental Petroleum OXY Chevron CVX HP HPQ Paramount PARA Taiwan Semiconductor TSM Citigroup C Activision ATVI Ally ALLY Celanese CE Apple AAPL LouisianaPacific LPX Floor amp Décor FND McKesson MCK RH RH Markel MKL Jefferies JEF',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609925625925750784',
#   'company': 'apple',
#   'post_date': '2023-01-02 14:52:34+00:00',
#   'author': 'Jake__Wujastyk',
#   'raw_text': '$AAPL #AAPL Short-term bull vs. bear case.\n\nBull: Move up to test the S/R flip zone above from $136-$137. \n\nBear: Breakdown through the Covid low VWAP to fill the gap at $120.40.\n\nBoth: Move up to the S/R flip zone, reject, continue downside through the Covid low VWAP to the gap. https://t.co/FyKFCFrtlI',
#   'like_num': 122,
#   'comment_num': 13,
#   'retweet_num': 13,
#   'tweet_activity': 148,
#   'clean_text': 'AAPL AAPL Shortterm bull vs bear case Bull Move test SR flip zone 136137 Bear Breakdown Covid low VWAP fill gap 12040 Both Move SR flip zone reject continue downside Covid low VWAP gap',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1609905434806325248',
#   'company': 'apple',
#   'post_date': '2023-01-02 13:32:20+00:00',
#   'author': 'JCOviedo6',
#   'raw_text': '$AAPL\n\n"Apple has notified several suppliers to build fewer components for AirPods, the Apple Watch and MacBooks for the first quarter, citing weakening demand, according to Nikkei Asia\'s supply chain checks with several component suppliers."\n\nhttps://t.co/fDDWFNOxqg',
#   'like_num': 97,
#   'comment_num': 4,
#   'retweet_num': 27,
#   'tweet_activity': 128,
#   'clean_text': 'AAPL Apple notified several suppliers build fewer components AirPods Apple Watch MacBooks first quarter citing weakening demand according Nikkei Asias supply chain checks several component suppliers',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1609900398969782272',
#   'company': 'apple',
#   'post_date': '2023-01-02 13:12:20+00:00',
#   'author': 'ShortsellerST',
#   'raw_text': '$AAPL inverted https://t.co/UpmqnhK7He',
#   'like_num': 117,
#   'comment_num': 16,
#   'retweet_num': 14,
#   'tweet_activity': 147,
#   'clean_text': 'AAPL inverted',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1609865590176366592',
#   'company': 'apple',
#   'post_date': '2023-01-02 10:54:01+00:00',
#   'author': 'ekmokaya',
#   'raw_text': 'Steve Jobs on teamwork at $AAPL: \n\n"There\'s tremendous teamwork at the top of the company which filters down to tremendous teamwork throughout the company. And teamwork is dependent on trusting the other folks to come through with their part without watching them all the time." https://t.co/UrhhY18tcn',
#   'like_num': 44,
#   'comment_num': 1,
#   'retweet_num': 14,
#   'tweet_activity': 59,
#   'clean_text': 'Steve Jobs teamwork AAPL Theres tremendous teamwork top company filters tremendous teamwork throughout company And teamwork dependent trusting folks come part without watching time',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610425530041651200',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:59:01+00:00',
#   'author': 'jj_buckner',
#   'raw_text': '$AAPL’s current dividend yield is at a 52-week high.',
#   'like_num': 56,
#   'comment_num': 7,
#   'retweet_num': 1,
#   'tweet_activity': 64,
#   'clean_text': 'AAPLs current dividend yield 52week high',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610425475481878528',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:58:48+00:00',
#   'author': 'Freshie305',
#   'raw_text': 'Maybe around 90$ on $AAPL I’m a buyer.',
#   'like_num': 31,
#   'comment_num': 4,
#   'retweet_num': 1,
#   'tweet_activity': 36,
#   'clean_text': 'Maybe around 90 AAPL Im buyer',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610422546947768320',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:47:10+00:00',
#   'author': 'The_RockTrading',
#   'raw_text': '$AAPL Apple falls 4% and drops below $2 trillion market valuation after report of weakening demand for its MacBooks and AirPods',
#   'like_num': 27,
#   'comment_num': 2,
#   'retweet_num': 4,
#   'tweet_activity': 33,
#   'clean_text': 'AAPL Apple falls 4 drops 2 trillion market valuation report weakening demand MacBooks AirPods',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610421786230800384',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:44:08+00:00',
#   'author': 'optionsmafia1',
#   'raw_text': 'First 🌶🌶🌶🌶🌶list of 2023 $AAPL $BAC $META $YOU https://t.co/uefocJm7dd',
#   'like_num': 65,
#   'comment_num': 1,
#   'retweet_num': 5,
#   'tweet_activity': 71,
#   'clean_text': 'First list 2023 AAPL BAC META YOU',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610421069290307584',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:41:17+00:00',
#   'author': 'PBInvesting',
#   'raw_text': 'My Favorite Bearish Setup are $AMD + $AAPL  📉\n\n- $AMD Daily Looks really bad...\n- Under 63/60 I think we can potentially see $60  \n\n- $AAPL At 52 Week lows... \n- Broke out of a major daily Bearflag today and a lot of selling volume! \n\nI play these w bflag breakdowns under VWAP📉 https://t.co/qFXuHH8bRC',
#   'like_num': 56,
#   'comment_num': 3,
#   'retweet_num': 5,
#   'tweet_activity': 64,
#   'clean_text': 'My Favorite Bearish Setup AMD AAPL AMD Daily Looks really bad Under 6360 I think potentially see 60 AAPL At 52 Week lows Broke major daily Bearflag today lot selling volume I play w bflag breakdowns VWAP',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610421012595867648',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:41:04+00:00',
#   'author': 'ProblemSniper',
#   'raw_text': '🌊 $AAPL flow looks very bearish. 115P into February and 105P into March. ☠️',
#   'like_num': 137,
#   'comment_num': 5,
#   'retweet_num': 20,
#   'tweet_activity': 162,
#   'clean_text': 'AAPL flow looks bearish 115P February 105P March',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610414123380264960',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:13:41+00:00',
#   'author': 'Jake__Wujastyk',
#   'raw_text': "$AAPL #AAPL Massive bearish engulfing candle/outside bar today.\n\nThe body of today's candle engulfed the last 3 day's bodies. \n\nGap fills below at $120.40. https://t.co/KQcSOU2JdW",
#   'like_num': 243,
#   'comment_num': 16,
#   'retweet_num': 20,
#   'tweet_activity': 279,
#   'clean_text': 'AAPL AAPL Massive bearish engulfing candleoutside bar today The body todays candle engulfed last 3 days bodies Gap fills 12040',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610413270166568960',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:10:18+00:00',
#   'author': 'The_RockTrading',
#   'raw_text': "$AAPL Coming in hot! If 120 doesn't hold...116 support. But below that is a wide open volume gap. Pre-covid highs 82 range. https://t.co/WSPo5CLbez",
#   'like_num': 32,
#   'comment_num': 0,
#   'retweet_num': 3,
#   'tweet_activity': 35,
#   'clean_text': 'AAPL Coming hot If 120 doesnt hold116 support But wide open volume gap Precovid highs 82 range',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610410911126228992',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:00:55+00:00',
#   'author': 'CNBCOvertime',
#   'raw_text': "$AAPL hitting a 52-week low today, falling below a $2T market cap for the first time since March 2021. Here's where @jkrinskypga sees the stock going from here: https://t.co/gbxER8LkLt",
#   'like_num': 61,
#   'comment_num': 7,
#   'retweet_num': 8,
#   'tweet_activity': 76,
#   'clean_text': 'AAPL hitting 52week low today falling 2T market cap first time since March 2021 Heres jkrinskypga sees stock going',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610410681206980608',
#   'company': 'apple',
#   'post_date': '2023-01-03 23:00:01+00:00',
#   'author': 'TrendSpider',
#   'raw_text': '$AAPL Sellers with a statement today, engulfing candle on volume brings Apple to new 52-week lows! 🍎\n\nhttps://t.co/Rh1xpboRAe',
#   'like_num': 64,
#   'comment_num': 4,
#   'retweet_num': 9,
#   'tweet_activity': 77,
#   'clean_text': 'AAPL Sellers statement today engulfing candle volume brings Apple new 52week lows',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610407151884959744',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:45:59+00:00',
#   'author': 'cperruna',
#   'raw_text': '$AAPL - $125.07\n\nApple sets a new 52wk low on the 1st day of trading in 2023.\n\nStage 4 decline, under the 200d ma.\n\n$115 is the 2 year low. https://t.co/jPENgMMk8Q',
#   'like_num': 81,
#   'comment_num': 5,
#   'retweet_num': 4,
#   'tweet_activity': 90,
#   'clean_text': 'AAPL 12507 Apple sets new 52wk low 1st day trading 2023 Stage 4 decline 200d 115 2 year low',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610403130612621312',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:30:00+00:00',
#   'author': 'TrendSpider',
#   'raw_text': 'Bearish engulfing candles coupled with above average volume can be useful in showing extreme aggression from sellers.🐻\n\nToday there were 22 bearish engulfing candles in the S&amp;P 500 with daily volume above their 20 SMAs✅\n\n$AAPL $ETSY $QCOM $LUV $WBA\n\nhttps://t.co/RjSwBklPIS',
#   'like_num': 31,
#   'comment_num': 3,
#   'retweet_num': 4,
#   'tweet_activity': 38,
#   'clean_text': 'Bearish engulfing candles coupled average volume useful showing extreme aggression sellers Today 22 bearish engulfing candles Samp 500 daily volume 20 SMAs AAPL ETSY QCOM LUV WBA',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610400930146525184',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:21:16+00:00',
#   'author': 'MasterBJones',
#   'raw_text': "I'm still not making long term trades.\nBecause if $AAPL continues to be attacked by the shorts and drops lower in the next few months.\n The major market will be going down too and so will most other stocks.",
#   'like_num': 57,
#   'comment_num': 3,
#   'retweet_num': 4,
#   'tweet_activity': 64,
#   'clean_text': 'Im still making long term trades Because AAPL continues attacked shorts drops lower next months The major market going stocks',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610399886758772736',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:17:07+00:00',
#   'author': 'CNBCFastMoney',
#   'raw_text': 'A rotten start to the new year! $AAPL sinks below the $2T mark, hitting their lowest shares since June 2021.\n\n@GuyAdami @timseymour @karenfinerman and @RiskReversal discuss what the year ahead has in store for this tech stock. https://t.co/vePKAiDbQe',
#   'like_num': 43,
#   'comment_num': 12,
#   'retweet_num': 7,
#   'tweet_activity': 62,
#   'clean_text': 'A rotten start new year AAPL sinks 2T mark hitting lowest shares since June 2021 GuyAdami timseymour karenfinerman RiskReversal discuss year ahead store tech stock',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610398824085786624',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:12:54+00:00',
#   'author': 'MasterBJones',
#   'raw_text': "$AAPL\nIt's in a down trend.\n#1 reason why the market has not been doing well.\n  Can't get excited after it makes it's usual bounce over the 50 sma on the 10 day chart because it always gets shot down again. https://t.co/1SHK7Q3jqd",
#   'like_num': 62,
#   'comment_num': 1,
#   'retweet_num': 4,
#   'tweet_activity': 67,
#   'clean_text': 'AAPL Its trend 1 reason market well Cant get excited makes usual bounce 50 sma 10 day chart always gets shot',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610397938009735168',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:09:22+00:00',
#   'author': 'ElliottForecast',
#   'raw_text': "$NQ_F The Index should trade lower at the begining of 2023, and provide a nice buying opportunity. Here is the latest Weekly view to member's at https://t.co/m32Lpb6ujJ, showing the idea. #elliottwave #trading $QQQ $SPX $ES_F $SPY $XLK $AAPL $AMAZ $META https://t.co/EoV8gFLf7x",
#   'like_num': 25,
#   'comment_num': 0,
#   'retweet_num': 11,
#   'tweet_activity': 36,
#   'clean_text': 'NQF The Index trade lower begining 2023 provide nice buying opportunity Here latest Weekly view members showing idea elliottwave trading QQQ SPX ESF SPY XLK AAPL AMAZ META',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610396833003470848',
#   'company': 'apple',
#   'post_date': '2023-01-03 22:04:59+00:00',
#   'author': 'TripleDTrader',
#   'raw_text': "Message me when $AAPL's P/E is 15.",
#   'like_num': 25,
#   'comment_num': 5,
#   'retweet_num': 0,
#   'tweet_activity': 30,
#   'clean_text': 'Message AAPLs PE 15',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610391885457281024',
#   'company': 'apple',
#   'post_date': '2023-01-03 21:45:19+00:00',
#   'author': 'Investingcom',
#   'raw_text': "*APPLE'S MARKET CAP FALLS BELOW $2 TRILLION FOR FIRST TIME SINCE 2021 AS SELLOFF CONTINUES - https://t.co/T0fZrC8LRd \n\n$AAPL https://t.co/OLIQFRz0WG",
#   'like_num': 162,
#   'comment_num': 11,
#   'retweet_num': 24,
#   'tweet_activity': 197,
#   'clean_text': 'APPLES MARKET CAP FALLS BELOW 2 TRILLION FOR FIRST TIME SINCE 2021 AS SELLOFF CONTINUES AAPL',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610390966883520512',
#   'company': 'apple',
#   'post_date': '2023-01-03 21:41:40+00:00',
#   'author': 'dividend_data',
#   'raw_text': 'Bought 1 share of $AAPL at $124.7',
#   'like_num': 128,
#   'comment_num': 7,
#   'retweet_num': 4,
#   'tweet_activity': 139,
#   'clean_text': 'Bought 1 share AAPL 1247',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610389111952523264',
#   'company': 'apple',
#   'post_date': '2023-01-03 21:34:18+00:00',
#   'author': 'CNBCOvertime',
#   'raw_text': '"At some point investors are going to say the jig is up [for $AAPL]," says Trivariate\'s Adam Parker. "It\'s unclear they have as much pricing power as some of the other businesses that have sold off hard...talking about replicating what they\'ve built." https://t.co/fFnJTFkHLT',
#   'like_num': 24,
#   'comment_num': 7,
#   'retweet_num': 2,
#   'tweet_activity': 33,
#   'clean_text': 'At point investors going say jig AAPL says Trivariates Adam Parker Its unclear much pricing power businesses sold hardtalking replicating theyve built',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610388080434847744',
#   'company': 'apple',
#   'post_date': '2023-01-03 21:30:12+00:00',
#   'author': 'Investingcom',
#   'raw_text': '⚠️BREAKING: \n\n*APPLE SHARES FALL 3.7% TO CLOSE AT LOWEST LEVEL SINCE JUNE 2021\n\n$AAPL https://t.co/Owe8XR6yYN',
#   'like_num': 156,
#   'comment_num': 11,
#   'retweet_num': 24,
#   'tweet_activity': 191,
#   'clean_text': 'BREAKING APPLE SHARES FALL 37 TO CLOSE AT LOWEST LEVEL SINCE JUNE 2021 AAPL',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1610782018933063680',
#   'company': 'apple',
#   'post_date': '2023-01-04 23:35:34+00:00',
#   'author': 'CNBCOvertime',
#   'raw_text': '"The bears continue to think [ $AAPL ] is a name that\'s going to go to a market multiple or less," says @DivesTech. "Where I strongly disagree...this is a company...you could actually rationalize could be north of $200." https://t.co/cznx476Oux',
#   'like_num': 98,
#   'comment_num': 27,
#   'retweet_num': 16,
#   'tweet_activity': 141,
#   'clean_text': 'The bears continue think AAPL name thats going go market multiple less says DivesTech Where I strongly disagreethis companyyou could actually rationalize could north 200',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1610778756007825408',
#   'company': 'apple',
#   'post_date': '2023-01-04 23:22:36+00:00',
#   'author': 'CNBCOvertime',
#   'raw_text': '"Our Asia checks over the last week are showing some softening on non-iPhones...as well as what I view as just a lower multiple in this market," says @DivesTech on why he cut his $AAPL price target to $175 from $200 https://t.co/YJazFdWUGi',
#   'like_num': 56,
#   'comment_num': 8,
#   'retweet_num': 9,
#   'tweet_activity': 73,
#   'clean_text': 'Our Asia checks last week showing softening noniPhonesas well I view lower multiple market says DivesTech cut AAPL price target 175 200',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610770123173908480',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:48:18+00:00',
#   'author': 'StockMKTNewz',
#   'raw_text': 'Apple $AAPL closed today back over a $2 Trillion market cap',
#   'like_num': 75,
#   'comment_num': 0,
#   'retweet_num': 8,
#   'tweet_activity': 83,
#   'clean_text': 'Apple AAPL closed today back 2 Trillion market cap',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610768390125400064',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:41:25+00:00',
#   'author': 'BigBullCap',
#   'raw_text': "$AAPL Foxconn's biggest Chinese rival wins premium Apple iPhone contract - FT",
#   'like_num': 31,
#   'comment_num': 3,
#   'retweet_num': 2,
#   'tweet_activity': 36,
#   'clean_text': 'AAPL Foxconns biggest Chinese rival wins premium Apple iPhone contract FT',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610767829778792448',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:39:11+00:00',
#   'author': 'appleinsider',
#   'raw_text': 'Apple will announce details of its earnings for the first fiscal quarter of 2023 on Feb. 2, with its typical results accompanied by a conference call featuring CEO Tim Cook and CFO Luca Maestri $aapl https://t.co/r2tv6qwQae https://t.co/Fi7PamnTjI',
#   'like_num': 38,
#   'comment_num': 0,
#   'retweet_num': 4,
#   'tweet_activity': 42,
#   'clean_text': 'Apple announce details earnings first fiscal quarter 2023 Feb 2 typical results accompanied conference call featuring CEO Tim Cook CFO Luca Maestri aapl',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610764510918283264',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:26:00+00:00',
#   'author': 'appleinsider',
#   'raw_text': "On Tuesday, Apple's market cap fell below the $2 trillion mark over investor fears -- but a positive day has returned the stock to over the line.\n\n$aapl https://t.co/Vps6Sm72OT https://t.co/j2CiSk1iWC",
#   'like_num': 33,
#   'comment_num': 1,
#   'retweet_num': 3,
#   'tweet_activity': 37,
#   'clean_text': 'On Tuesday Apples market cap fell 2 trillion mark investor fears positive day returned stock line aapl',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610762198573322240',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:16:49+00:00',
#   'author': 'StockMKTNewz',
#   'raw_text': 'Apple $AAPL just announced it will host its FYQ1 earnings after the markets close on Thursday, February 2nd',
#   'like_num': 141,
#   'comment_num': 8,
#   'retweet_num': 17,
#   'tweet_activity': 166,
#   'clean_text': 'Apple AAPL announced host FYQ1 earnings markets close Thursday February 2nd',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610758187480944640',
#   'company': 'apple',
#   'post_date': '2023-01-04 22:00:52+00:00',
#   'author': 'ZTheTrader',
#   'raw_text': 'Shorted $AAPL yesterday after spotting the bearish engulfing candle. Currently down 12% on the position but it expires in in 1.5 months. This will be the last stock to fall but it might not be a comfortable hold. https://t.co/JCmoR41xBq',
#   'like_num': 51,
#   'comment_num': 9,
#   'retweet_num': 0,
#   'tweet_activity': 60,
#   'clean_text': 'Shorted AAPL yesterday spotting bearish engulfing candle Currently 12 position expires 15 months This last stock fall might comfortable hold',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610756833861373952',
#   'company': 'apple',
#   'post_date': '2023-01-04 21:55:30+00:00',
#   'author': 'MarketRebels',
#   'raw_text': '$AAPL to reportedly sign up Luxshare to produce iPhones in China',
#   'like_num': 19,
#   'comment_num': 5,
#   'retweet_num': 1,
#   'tweet_activity': 25,
#   'clean_text': 'AAPL reportedly sign Luxshare produce iPhones China',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610754237004189696',
#   'company': 'apple',
#   'post_date': '2023-01-04 21:45:11+00:00',
#   'author': 'StockMKTNewz',
#   'raw_text': 'APPLE $AAPL TO SIGN UP LUXSHARE TO PRODUCE IPHONES IN CHINA - FT',
#   'like_num': 37,
#   'comment_num': 4,
#   'retweet_num': 3,
#   'tweet_activity': 44,
#   'clean_text': 'APPLE AAPL TO SIGN UP LUXSHARE TO PRODUCE IPHONES IN CHINA FT',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610747184533889024',
#   'company': 'apple',
#   'post_date': '2023-01-04 21:17:09+00:00',
#   'author': 'Gfilche',
#   'raw_text': "new $AAPL headset (AR/VR) rumors \n\nwe might see innovation for the first time in the @tim_cook era! lowkey very excited. but also think this is going to flop unless it's very well executed ... https://t.co/EH2u9ewBa7",
#   'like_num': 245,
#   'comment_num': 38,
#   'retweet_num': 9,
#   'tweet_activity': 292,
#   'clean_text': 'new AAPL headset ARVR rumors might see innovation first time timcook era lowkey excited also think going flop unless well executed',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1610741779136905216',
#   'company': 'apple',
#   'post_date': '2023-01-04 20:55:40+00:00',
#   'author': 'CheddarFlow',
#   'raw_text': '$AAPL $1.2M Put \n \nStrike: 125 \nExpiration: 3/17/23 https://t.co/LojHZRGhY4',
#   'like_num': 51,
#   'comment_num': 0,
#   'retweet_num': 7,
#   'tweet_activity': 58,
#   'clean_text': 'AAPL 12M Put Strike 125 Expiration 31723',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1610729126767345664',
#   'company': 'apple',
#   'post_date': '2023-01-04 20:05:24+00:00',
#   'author': 'BCalusinski',
#   'raw_text': 'They own the largest company in the world and tech sector $AAPL https://t.co/1Wdw7HzJaE',
#   'like_num': 52,
#   'comment_num': 1,
#   'retweet_num': 2,
#   'tweet_activity': 55,
#   'clean_text': 'They largest company world tech sector AAPL',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610709835351490560',
#   'company': 'apple',
#   'post_date': '2023-01-04 18:48:44+00:00',
#   'author': 'TheDividendDog',
#   'raw_text': 'With $AAPL even if we go into a deep recession, people will always find a way to upgrade their phones.',
#   'like_num': 110,
#   'comment_num': 20,
#   'retweet_num': 0,
#   'tweet_activity': 130,
#   'clean_text': 'With AAPL even go deep recession people always find way upgrade phones',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610709027062792192',
#   'company': 'apple',
#   'post_date': '2023-01-04 18:45:32+00:00',
#   'author': 'unusual_whales',
#   'raw_text': 'Recent bearish OTM flow (15 Minute delayed): \n\n$EA put $110 2023-03-17 - Prem: $138,400\n$AAPL put $105 2023-09-15 - Prem: $59,292\n$ATVI put $65 2023-02-17 - Prem: $320,000\n$ATVI put $70 2024-01-19 - Prem: $1,265,000\n\n Link (+ live flow): https://t.co/cQqFusdBjs https://t.co/RavzPhkQY1',
#   'like_num': 24,
#   'comment_num': 5,
#   'retweet_num': 6,
#   'tweet_activity': 35,
#   'clean_text': 'Recent bearish OTM flow 15 Minute delayed EA put 110 20230317 Prem 138400 AAPL put 105 20230915 Prem 59292 ATVI put 65 20230217 Prem 320000 ATVI put 70 20240119 Prem 1265000 Link live flow',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1610706581959720960',
#   'company': 'apple',
#   'post_date': '2023-01-04 18:35:49+00:00',
#   'author': 'compound248',
#   'raw_text': '“I want a high speed [manufacturing] machine that also gets run by people who earn two-bucks an hour.” 😬\n\nT.J. Rogers, Executive Chairman of $ENVX, on how to succeed manufacturing battery tech for consumer devices\n\nHelps explain why $AAPL has such high margins… 👀 https://t.co/lQf7ZBSOFx',
#   'like_num': 63,
#   'comment_num': 12,
#   'retweet_num': 7,
#   'tweet_activity': 82,
#   'clean_text': 'I want high speed manufacturing machine also gets run people earn twobucks hour TJ Rogers Executive Chairman ENVX succeed manufacturing battery tech consumer devices Helps explain AAPL high margins',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610700149197770752',
#   'company': 'apple',
#   'post_date': '2023-01-04 18:10:15+00:00',
#   'author': 'blakestonks',
#   'raw_text': "Make 2023 the year of consistency with base hits.\n\nYou'll get a lot farther than you think.\n\n+$1,113.73 on the day &amp; +$3,684.00 on the week so far.\n\nTraded:\n$AAPL ( x2 )\n$LVS https://t.co/auMXvYDpgd",
#   'like_num': 183,
#   'comment_num': 9,
#   'retweet_num': 5,
#   'tweet_activity': 197,
#   'clean_text': 'Make 2023 year consistency base hits Youll get lot farther think 111373 day amp 368400 week far Traded AAPL x2 LVS',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610694685005156352',
#   'company': 'apple',
#   'post_date': '2023-01-04 17:48:32+00:00',
#   'author': 'Tradytics',
#   'raw_text': "One of the things I tend to do when trading is always to keep an eye on $AAPL in regards to where it is in it's levels compared to $SPY. This video  shows how I use the GEX levels on both $AAPL &amp; $SPY to help me get a bigger picture of the overall market! 🍿 https://t.co/ywBG4xDhMg",
#   'like_num': 29,
#   'comment_num': 4,
#   'retweet_num': 3,
#   'tweet_activity': 36,
#   'clean_text': 'One things I tend trading always keep eye AAPL regards levels compared SPY This video shows I use GEX levels AAPL amp SPY help get bigger picture overall market',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1610689438623100928',
#   'company': 'apple',
#   'post_date': '2023-01-04 17:27:41+00:00',
#   'author': 'TicTocTick',
#   'raw_text': 'Berkshire stock soon gonna start trading like tech stock $brk.a $brk.b $aapl',
#   'like_num': 108,
#   'comment_num': 11,
#   'retweet_num': 3,
#   'tweet_activity': 122,
#   'clean_text': 'Berkshire stock soon gon na start trading like tech stock brka brkb aapl',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1610679643933376512',
#   'company': 'apple',
#   'post_date': '2023-01-04 16:48:46+00:00',
#   'author': 'StockMKTNewz',
#   'raw_text': 'APPLE $AAPL FINED €8MLN BY FRENCH DATA WATCHDOG',
#   'like_num': 44,
#   'comment_num': 7,
#   'retweet_num': 7,
#   'tweet_activity': 58,
#   'clean_text': 'APPLE AAPL FINED 8MLN BY FRENCH DATA WATCHDOG',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611138874767544320',
#   'company': 'apple',
#   'post_date': '2023-01-05 23:13:35+00:00',
#   'author': 'MasterBJones',
#   'raw_text': 'We said that $AAPL is in a down trend and it would break over the 50 sma then sell off again.\n Exactly what happened.\nYou know stock trading is not as hard as they say it is. https://t.co/5Pn0EVXM7B',
#   'like_num': 50,
#   'comment_num': 4,
#   'retweet_num': 2,
#   'tweet_activity': 56,
#   'clean_text': 'We said AAPL trend would break 50 sma sell Exactly happened You know stock trading hard say',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611137943279656960',
#   'company': 'apple',
#   'post_date': '2023-01-05 23:09:53+00:00',
#   'author': 'kiantrades',
#   'raw_text': 'Top Watches for Tomorrow 🎯\n\n$BX 60P 3/17exp $3.09M (19,900x volume)\n$STNE 10C 2/17exp $282k (5300x volume at the bell)\n$IQ 10C 2/17exp $1.97M (60,446 volume)\n$ISNP 240P 1/20exp $559k \n$SI 7.5P 2/17exp $205k\n$DASH 40P 2/17exp $748k\n$AAPL 120P sellers 4/21exp $2.79M\n\nGL everyone!',
#   'like_num': 74,
#   'comment_num': 9,
#   'retweet_num': 13,
#   'tweet_activity': 96,
#   'clean_text': 'Top Watches Tomorrow BX 60P 317exp 309M 19900x volume STNE 10C 217exp 282k 5300x volume bell IQ 10C 217exp 197M 60446 volume ISNP 240P 120exp 559k SI 75P 217exp 205k DASH 40P 217exp 748k AAPL 120P sellers 421exp 279M GL everyone',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611136882515099648',
#   'company': 'apple',
#   'post_date': '2023-01-05 23:05:40+00:00',
#   'author': 'TheTradingChamp',
#   'raw_text': '$AAPL Symmetrical Triangle Breakout Here To The Downside. $124 break is crucial for more downside https://t.co/7VBkhQD8ui',
#   'like_num': 42,
#   'comment_num': 2,
#   'retweet_num': 2,
#   'tweet_activity': 46,
#   'clean_text': 'AAPL Symmetrical Triangle Breakout Here To The Downside 124 break crucial downside',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611122403362635776',
#   'company': 'apple',
#   'post_date': '2023-01-05 22:08:08+00:00',
#   'author': 'CryptoParadyme',
#   'raw_text': 'the vibe is continuing to deteriorate $AAPL https://t.co/sbyQkNGMkr',
#   'like_num': 23,
#   'comment_num': 2,
#   'retweet_num': 0,
#   'tweet_activity': 25,
#   'clean_text': 'vibe continuing deteriorate AAPL',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611116394506063872',
#   'company': 'apple',
#   'post_date': '2023-01-05 21:44:16+00:00',
#   'author': 'ProblemSniper',
#   'raw_text': '📈 $SPY Day 13, still in range. Bouncing off the lower trendline. Cannot break the EMAs or 382. Nasty reversals and premium kills. Cannot hold anything for long. $AAPL showed good weakness into close. NFP tomorrow.\n\n[Personally positioned into a strangle (not weekly)] https://t.co/8UIWGV40Hu',
#   'like_num': 102,
#   'comment_num': 8,
#   'retweet_num': 13,
#   'tweet_activity': 123,
#   'clean_text': 'SPY Day 13 still range Bouncing lower trendline Can break EMAs 382 Nasty reversals premium kills Can hold anything long AAPL showed good weakness close NFP tomorrow Personally positioned strangle weekly',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611112878978830336',
#   'company': 'apple',
#   'post_date': '2023-01-05 21:30:18+00:00',
#   'author': 'CyberDog2',
#   'raw_text': 'If you took $AAPL on the 3-1-2 on the daily. Good for you. It was so slow, but did trigger. \n\n“My money don’t dribble dribble, it folds.” #theStrat https://t.co/blfkLN0O0C',
#   'like_num': 24,
#   'comment_num': 8,
#   'retweet_num': 0,
#   'tweet_activity': 32,
#   'clean_text': 'If took AAPL 312 daily Good It slow trigger My money dont dribble dribble folds theStrat',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611109403771428864',
#   'company': 'apple',
#   'post_date': '2023-01-05 21:16:29+00:00',
#   'author': '_mm85',
#   'raw_text': 'Huh? Everyone told me the next Apple contract is going out of China and to India or some other upcoming economy that is not collapsing according to Youtubers.\n\n$AAPL https://t.co/sITnVPT67M',
#   'like_num': 143,
#   'comment_num': 14,
#   'retweet_num': 17,
#   'tweet_activity': 174,
#   'clean_text': 'Huh Everyone told next Apple contract going China India upcoming economy collapsing according Youtubers AAPL',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611103374392401920',
#   'company': 'apple',
#   'post_date': '2023-01-05 20:52:31+00:00',
#   'author': 'tradertvshawn',
#   'raw_text': 'good trade to end the day here on $AAPL https://t.co/WdvdgJm4hB',
#   'like_num': 41,
#   'comment_num': 5,
#   'retweet_num': 1,
#   'tweet_activity': 47,
#   'clean_text': 'good trade end day AAPL',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611101472858456064',
#   'company': 'apple',
#   'post_date': '2023-01-05 20:44:58+00:00',
#   'author': 'David_Tracey',
#   'raw_text': 'Someone’s trying very hard to close $AAPL under $125 here',
#   'like_num': 22,
#   'comment_num': 5,
#   'retweet_num': 0,
#   'tweet_activity': 27,
#   'clean_text': 'Someones trying hard close AAPL 125',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611093858208874496',
#   'company': 'apple',
#   'post_date': '2023-01-05 20:14:43+00:00',
#   'author': 'Mr_Derivatives',
#   'raw_text': '$AAPL Likely lowest close since June 10th 2021.\n\nBiggest company in the world trading like shit recently. \n\nNo beating around the bush about it.',
#   'like_num': 160,
#   'comment_num': 17,
#   'retweet_num': 7,
#   'tweet_activity': 184,
#   'clean_text': 'AAPL Likely lowest close since June 10th 2021 Biggest company world trading like shit recently No beating around bush',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611092519944609792',
#   'company': 'apple',
#   'post_date': '2023-01-05 20:09:24+00:00',
#   'author': 'Mr_Derivatives',
#   'raw_text': '$AAPL \nDownside targets with gap fill potentials:\n\n$118.51\n\n$108.80 (coincides well with the 50% fib retracement)\n\n$94.60 (The massive big kahuna gap left in Aug 2020)',
#   'like_num': 160,
#   'comment_num': 8,
#   'retweet_num': 16,
#   'tweet_activity': 184,
#   'clean_text': 'AAPL Downside targets gap fill potentials 11851 10880 coincides well 50 fib retracement 9460 The massive big kahuna gap left Aug 2020',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611091528759537664',
#   'company': 'apple',
#   'post_date': '2023-01-05 20:05:27+00:00',
#   'author': 'Mr_Derivatives',
#   'raw_text': '$AAPL Apple hanging by a hairline to this 38.2% retrancement level. I think it breaks soon and goes down towards the 50.0% retracement before any meaningful bounce or another -13.8% downside here.\n\nPT: 108ish https://t.co/gkaLsIvHnz',
#   'like_num': 193,
#   'comment_num': 20,
#   'retweet_num': 17,
#   'tweet_activity': 230,
#   'clean_text': 'AAPL Apple hanging hairline 382 retrancement level I think breaks soon goes towards 500 retracement meaningful bounce another 138 downside PT 108ish',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611090057229656064',
#   'company': 'apple',
#   'post_date': '2023-01-05 19:59:36+00:00',
#   'author': 'ShortsellerST',
#   'raw_text': "$SPY If $AAPL wasn't in it .... sorry home gamers that's not bearish https://t.co/IHN1xp8M4f",
#   'like_num': 94,
#   'comment_num': 20,
#   'retweet_num': 11,
#   'tweet_activity': 125,
#   'clean_text': 'SPY If AAPL wasnt sorry home gamers thats bearish',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1611084262324723712',
#   'company': 'apple',
#   'post_date': '2023-01-05 19:36:35+00:00',
#   'author': 'CheddarFlow',
#   'raw_text': '$AAPL $1.1M Put \n \nStrike: 125 \nExpiration: 2/03/23 \n \n*Above the Ask* https://t.co/mrpfn12PQ5',
#   'like_num': 51,
#   'comment_num': 2,
#   'retweet_num': 10,
#   'tweet_activity': 63,
#   'clean_text': 'AAPL 11M Put Strike 125 Expiration 20323 Above Ask',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1611081854022553600',
#   'company': 'apple',
#   'post_date': '2023-01-05 19:27:01+00:00',
#   'author': 'coveredcalls',
#   'raw_text': 'Is now the time to start building a position in $AAPL? I joined the @HalftimeReport today with @ScottWapnerCNBC and shared my thoughts. \n⬇️⬇️⬇️⬇️\nhttps://t.co/CQYL321g1z',
#   'like_num': 21,
#   'comment_num': 2,
#   'retweet_num': 7,
#   'tweet_activity': 30,
#   'clean_text': 'Is time start building position AAPL I joined HalftimeReport today ScottWapnerCNBC shared thoughts',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1611081802806091776',
#   'company': 'apple',
#   'post_date': '2023-01-05 19:26:48+00:00',
#   'author': 'MasterBJones',
#   'raw_text': 'Now I think the longer term direction over the next few "months" will be down lead by $AAPL.\nI\'m at this point in the bearish side from what I\'m seeing.\n market would have to do a lot better than what I\'m seeing.',
#   'like_num': 39,
#   'comment_num': 2,
#   'retweet_num': 3,
#   'tweet_activity': 44,
#   'clean_text': 'Now I think longer term direction next months lead AAPL Im point bearish side Im seeing market would lot better Im seeing',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611493455561379840',
#   'company': 'apple',
#   'post_date': '2023-01-06 22:42:34+00:00',
#   'author': 'Rustyram78',
#   'raw_text': '$AAPL came out of nowhere in 2010 and shot straight to the top! https://t.co/HtqFpni3J2',
#   'like_num': 22,
#   'comment_num': 3,
#   'retweet_num': 4,
#   'tweet_activity': 29,
#   'clean_text': 'AAPL came nowhere 2010 shot straight top',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611488495960469504',
#   'company': 'apple',
#   'post_date': '2023-01-06 22:22:52+00:00',
#   'author': 'optionsmafia1',
#   'raw_text': '$AAPL trader up over $2M',
#   'like_num': 29,
#   'comment_num': 3,
#   'retweet_num': 1,
#   'tweet_activity': 33,
#   'clean_text': 'AAPL trader 2M',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1611478644781731840',
#   'company': 'apple',
#   'post_date': '2023-01-06 21:43:43+00:00',
#   'author': 'Mike09964617',
# ...
#   'like_num': 53,
#   'comment_num': 6,
#   'retweet_num': 10,
#   'tweet_activity': 69,
#   'clean_text': 'You need lot rally repair chart AMZN',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1611473968631894016',
#   'company': 'amazon',
#   'post_date': '2023-01-06 21:25:08+00:00',
#   'author': 'akramsrazor',
#   'raw_text': '$amzn Aws will "easily" grow 25% a year from here for next 3 years. I take the under.',
#   'like_num': 45,
#   'comment_num': 8,
#   'retweet_num': 2,
#   'tweet_activity': 55,
#   'clean_text': 'amzn Aws easily grow 25 year next 3 years I take',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611470702246301696',
#   'company': 'amazon',
#   'post_date': '2023-01-06 21:12:09+00:00',
#   'author': 'CNBCClosingBell',
#   'raw_text': 'See why Bill Miller of @MillerValue says "absolutely" @Amazon is due for a recovery\n$AMZN https://t.co/M8p6TUWctj',
#   'like_num': 134,
#   'comment_num': 5,
#   'retweet_num': 18,
#   'tweet_activity': 157,
#   'clean_text': 'See Bill Miller MillerValue says absolutely Amazon due recovery AMZN',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611468367944208384',
#   'company': 'amazon',
#   'post_date': '2023-01-06 21:02:53+00:00',
#   'author': 'MarketRebels',
#   'raw_text': '$AMZN finishes up 3.56% to $86.08',
#   'like_num': 42,
#   'comment_num': 5,
#   'retweet_num': 4,
#   'tweet_activity': 51,
#   'clean_text': 'AMZN finishes 356 8608',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1611453329405517824',
#   'company': 'amazon',
#   'post_date': '2023-01-06 20:03:07+00:00',
#   'author': 'claireatki',
#   'raw_text': "Inside Amazon, there's chatter, and jokes, about Jeff Bezos coming back as CEO in the midst of massive layoffs and a plummeting stock price. Is @eugenekim222 the best on Amazon beat? I think so.  $AMZN https://t.co/14CPgrvcgE via @businessinsider",
#   'like_num': 14,
#   'comment_num': 0,
#   'retweet_num': 7,
#   'tweet_activity': 21,
#   'clean_text': 'Inside Amazon theres chatter jokes Jeff Bezos coming back CEO midst massive layoffs plummeting stock price Is eugenekim222 best Amazon beat I think AMZN via businessinsider',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611443994042503168',
#   'company': 'amazon',
#   'post_date': '2023-01-06 19:26:02+00:00',
#   'author': 'CheddarFlow',
#   'raw_text': '$AMZN &amp; $CVX $1M+ Calls https://t.co/Ls07okn5Zh',
#   'like_num': 37,
#   'comment_num': 3,
#   'retweet_num': 3,
#   'tweet_activity': 43,
#   'clean_text': 'AMZN amp CVX 1M Calls',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1611443224630988800',
#   'company': 'amazon',
#   'post_date': '2023-01-06 19:22:58+00:00',
#   'author': 'JaviCharts',
#   'raw_text': "$AMZN that's a @RedDogT3 reversal of 5% on ole amazon today\n\nhttps://t.co/O6DeOAVz4P https://t.co/9ZkkeXID6G",
#   'like_num': 21,
#   'comment_num': 2,
#   'retweet_num': 5,
#   'tweet_activity': 28,
#   'clean_text': 'AMZN thats RedDogT3 reversal 5 ole amazon today',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611426446970609664',
#   'company': 'amazon',
#   'post_date': '2023-01-06 18:16:18+00:00',
#   'author': 'TimMarkets',
#   'raw_text': 'Amazon Stock Review\n\n#Amazon $amzn https://t.co/eHdRkYfeer',
#   'like_num': 37,
#   'comment_num': 3,
#   'retweet_num': 4,
#   'tweet_activity': 44,
#   'clean_text': 'Amazon Stock Review Amazon amzn',
#   'subjectivity': 0,
#   'sentiment': 0.0},
#  {'id': '1611419692362567680',
#   'company': 'amazon',
#   'post_date': '2023-01-06 17:49:28+00:00',
#   'author': 'CNBCTechCheck',
#   'raw_text': "$AMZN's shifting gears into auto tech 🚗 SVP of Devices &amp; Services Dave Limp joins after the e-commerce giant announced a slate of new products at @CES, including a dual-facing car camera from @ring. https://t.co/vewWaMcVbi",
#   'like_num': 16,
#   'comment_num': 5,
#   'retweet_num': 4,
#   'tweet_activity': 25,
#   'clean_text': 'AMZNs shifting gears auto tech SVP Devices amp Services Dave Limp joins ecommerce giant announced slate new products CES including dualfacing car camera ring',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1611416648334086144',
#   'company': 'amazon',
#   'post_date': '2023-01-06 17:37:22+00:00',
#   'author': 'LogicalThesis',
#   'raw_text': "I went long $amzn and it feels good. It can go lower, but -55% seems like a big correction for what I think will be undoubtedly the largest company on earth. It's the most essential. Biggest reach and potential\nGlad I finally have some cloud exposure too, my expertise",
#   'like_num': 32,
#   'comment_num': 7,
#   'retweet_num': 0,
#   'tweet_activity': 39,
#   'clean_text': 'I went long amzn feels good It go lower 55 seems like big correction I think undoubtedly largest company earth Its essential Biggest reach potential Glad I finally cloud exposure expertise',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611406922552328192',
#   'company': 'amazon',
#   'post_date': '2023-01-06 16:58:43+00:00',
#   'author': 'cvpayne',
#   'raw_text': "$WWE +22% (Jan calls +2900%) on Vince McMahon's return - what if Jeff Bezos came back to $AMZN? \nCan't wait to ask @jonnajarian in Options School on Making Money. https://t.co/DirF428tOt",
#   'like_num': 85,
#   'comment_num': 15,
#   'retweet_num': 12,
#   'tweet_activity': 112,
#   'clean_text': 'WWE 22 Jan calls 2900 Vince McMahons return Jeff Bezos came back AMZN Cant wait ask jonnajarian Options School Making Money',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1611404224666943488',
#   'company': 'amazon',
#   'post_date': '2023-01-06 16:48:00+00:00',
#   'author': 'Matt_Cochrane7',
#   'raw_text': '"The primary health care experience in this country is very bad and it\'s in dire need of being reinvented."\n\nAmazon $AMZN CEO Andy Jassy on the company\'s health care ambitions and the plans for One Medical $ONEM acquisition \n\n@DanaAbramovitz7 @7Innovator https://t.co/GAzQhmja1j',
#   'like_num': 25,
#   'comment_num': 0,
#   'retweet_num': 2,
#   'tweet_activity': 27,
#   'clean_text': 'The primary health care experience country bad dire need reinvented Amazon AMZN CEO Andy Jassy companys health care ambitions plans One Medical ONEM acquisition DanaAbramovitz7 7Innovator',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611393781709824000',
#   'company': 'amazon',
#   'post_date': '2023-01-06 16:06:30+00:00',
#   'author': 'vnkumarvnk',
#   'raw_text': '$COST holiday sales news can help market move up short term IMO.. \n\n$SHOP $AMZN $TGT $WMT',
#   'like_num': 24,
#   'comment_num': 4,
#   'retweet_num': 2,
#   'tweet_activity': 30,
#   'clean_text': 'COST holiday sales news help market move short term IMO SHOP AMZN TGT WMT',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611373689383043072',
#   'company': 'amazon',
#   'post_date': '2023-01-06 14:46:40+00:00',
#   'author': 'TidefallCapital',
#   'raw_text': '$AMZN down to 50x forward earnings ;)',
#   'like_num': 34,
#   'comment_num': 7,
#   'retweet_num': 0,
#   'tweet_activity': 41,
#   'clean_text': 'AMZN 50x forward earnings',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611373101345902592',
#   'company': 'amazon',
#   'post_date': '2023-01-06 14:44:19+00:00',
#   'author': 'StockMKTNewz',
#   'raw_text': 'Amazon $AMZN just hit new 52 Week Lows at $81.62',
#   'like_num': 77,
#   'comment_num': 4,
#   'retweet_num': 8,
#   'tweet_activity': 89,
#   'clean_text': 'Amazon AMZN hit new 52 Week Lows 8162',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611369809941495808',
#   'company': 'amazon',
#   'post_date': '2023-01-06 14:31:15+00:00',
#   'author': 'PythiaR',
#   'raw_text': 'If there’s one thing we can be sure of, it’s that whether the market is red or green, $amzn will be down.',
#   'like_num': 51,
#   'comment_num': 5,
#   'retweet_num': 1,
#   'tweet_activity': 57,
#   'clean_text': 'If theres one thing sure whether market red green amzn',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611366264236040192',
#   'company': 'amazon',
#   'post_date': '2023-01-06 14:17:09+00:00',
#   'author': 'unusual_whales',
#   'raw_text': 'Amazon, $AMZN, will fire 1,000 employees in India, per Times of India.',
#   'like_num': 239,
#   'comment_num': 11,
#   'retweet_num': 31,
#   'tweet_activity': 281,
#   'clean_text': 'Amazon AMZN fire 1000 employees India per Times India',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611867414878208000',
#   'company': 'amazon',
#   'post_date': '2023-01-07 23:28:33+00:00',
#   'author': 'RJRCapital',
#   'raw_text': "I've been an $AMZN bear for awhile, and although I still think the stock is richly priced, this Amazon Style store concept is solid and unique. @amazonholder1",
#   'like_num': 29,
#   'comment_num': 5,
#   'retweet_num': 0,
#   'tweet_activity': 34,
#   'clean_text': 'Ive AMZN bear awhile although I still think stock richly priced Amazon Style store concept solid unique amazonholder1',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611835391211982848',
#   'company': 'amazon',
#   'post_date': '2023-01-07 21:21:18+00:00',
#   'author': 'TheTranscript_',
#   'raw_text': 'Delta Airlines CEO: "During the pandemic, we signed a deal with Amazon AWS where we are halfway through moving virtually our entire mainframe technology base to the cloud we\'re not done yet...we are about halfway through...we\'ll be done with it by 2024" $AMZN $DAL $IBM https://t.co/rJAyEKSMwB',
#   'like_num': 25,
#   'comment_num': 0,
#   'retweet_num': 4,
#   'tweet_activity': 29,
#   'clean_text': 'Delta Airlines CEO During pandemic signed deal Amazon AWS halfway moving virtually entire mainframe technology base cloud done yetwe halfway throughwell done 2024 AMZN DAL IBM',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1611802903211118592',
#   'company': 'amazon',
#   'post_date': '2023-01-07 19:12:12+00:00',
#   'author': 'kerberos007',
#   'raw_text': '3) Tesla lost ~$900B in market capitalization in 2022. \n\n$AMZN market cap as of January 06, 2023=$847.96B\nJuly 2021 = 1.88T ATH \nlost 1T from ATH\n\n$META market cap as of January 06, 2023=$336.59B\nSep 2021 = 1.06T ATH\nlost 723B from ATH\n\nPowell 2022 rug-pull &amp; tech-wreck continue',
#   'like_num': 25,
#   'comment_num': 1,
#   'retweet_num': 1,
#   'tweet_activity': 27,
#   'clean_text': '3 Tesla lost 900B market capitalization 2022 AMZN market cap January 06 202384796B July 2021 188T ATH lost 1T ATH META market cap January 06 202333659B Sep 2021 106T ATH lost 723B ATH Powell 2022 rugpull amp techwreck continue',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611797765448929280',
#   'company': 'amazon',
#   'post_date': '2023-01-07 18:51:47+00:00',
#   'author': 'VSoien',
#   'raw_text': '$AMZN earnings expectations $145B!🤔 https://t.co/Wn4HlZqWiK',
#   'like_num': 22,
#   'comment_num': 3,
#   'retweet_num': 1,
#   'tweet_activity': 26,
#   'clean_text': 'AMZN earnings expectations 145B',
#   'subjectivity': 0,
#   'sentiment': 1.0},
#  {'id': '1611709307308883968',
#   'company': 'amazon',
#   'post_date': '2023-01-07 13:00:17+00:00',
#   'author': 'Invesquotes',
#   'raw_text': '1/ The risks of under-hiring during COVID were much much higher than the risks of over-hiring for $AMZN imho\n\nUnder-hiring: opportunity for competitors to take market share\n\nOver-hiring: retain/expand market leadership at the expense of short to medium term margins',
#   'like_num': 69,
#   'comment_num': 8,
#   'retweet_num': 4,
#   'tweet_activity': 81,
#   'clean_text': '1 The risks underhiring COVID much much higher risks overhiring AMZN imho Underhiring opportunity competitors take market share Overhiring retainexpand market leadership expense short medium term margins',
#   'subjectivity': 1,
#   'sentiment': -0.5},
#  {'id': '1611708440057098240',
#   'company': 'amazon',
#   'post_date': '2023-01-07 12:56:50+00:00',
#   'author': 'FiSavvy',
#   'raw_text': '3. $AMZN\n\nStrong competitive advantages &amp; very cheap valuation. Currently facing macro headwinds in retail, but is expanding into higher-margin cloud businesses, 3rd party sales, and advertising\n\nThe potential of the AWS business alone justifies the current valuation',
#   'like_num': 28,
#   'comment_num': 2,
#   'retweet_num': 2,
#   'tweet_activity': 32,
#   'clean_text': '3 AMZN Strong competitive advantages amp cheap valuation Currently facing macro headwinds retail expanding highermargin cloud businesses 3rd party sales advertising The potential AWS business alone justifies current valuation',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611658238092808192',
#   'company': 'amazon',
#   'post_date': '2023-01-07 09:37:21+00:00',
#   'author': 'Larryjamieson_',
#   'raw_text': '3 stock port that I think will do well from here:\n\n$BTI\n$AMZN\n$FICO',
#   'like_num': 58,
#   'comment_num': 10,
#   'retweet_num': 2,
#   'tweet_activity': 70,
#   'clean_text': '3 stock port I think well BTI AMZN FICO',
#   'subjectivity': 1,
#   'sentiment': 1.0},
#  {'id': '1611630987837939712',
#   'company': 'amazon',
#   'post_date': '2023-01-07 07:49:04+00:00',
#   'author': 'CiovaccoCapital',
#   'raw_text': 'Bullish Odds Improving with New Leadership\n\nStock Charts, Studies, &amp; Details: https://t.co/iuLMmptOmr\n\n#NFP #StockMarket #TechnicalAnalysis #Inflation $VTV $EFA $EFV $GLD #Gold $JNK $DIA $AMZN $SPX $SPY $VOO $IVV $HYG $LQD $TLT $IEF $EMB $JPST $TIP https://t.co/7MzVbBwxKD',
#   'like_num': 126,
#   'comment_num': 17,
#   'retweet_num': 18,
#   'tweet_activity': 161,
#   'clean_text': 'Bullish Odds Improving New Leadership Stock Charts Studies amp Details NFP StockMarket TechnicalAnalysis Inflation VTV EFA EFV GLD Gold JNK DIA AMZN SPX SPY VOO IVV HYG LQD TLT IEF EMB JPST TIP',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  {'id': '1611602591959457792',
#   'company': 'amazon',
#   'post_date': '2023-01-07 05:56:14+00:00',
#   'author': 'FlyrUsr',
#   'raw_text': '$AMZN workers at DEN4 in Colorado say an elderly worker died on the job on 12/28 after returning from a medical leave and instead of shutting down the area, Amazon managers stacked boxes around the body until a coroner could arrive so they could keep workers working through it https://t.co/aj64D1Q3a3',
#   'like_num': 18,
#   'comment_num': 3,
#   'retweet_num': 3,
#   'tweet_activity': 24,
#   'clean_text': 'AMZN workers DEN4 Colorado say elderly worker died job 1228 returning medical leave instead shutting area Amazon managers stacked boxes around body coroner could arrive could keep workers working',
#   'subjectivity': 0,
#   'sentiment': -0.5},
#  {'id': '1611568769784053760',
#   'company': 'amazon',
#   'post_date': '2023-01-07 03:41:50+00:00',
#   'author': 'NestBetter',
#   'raw_text': "$AMZN reverse to pre-pandemic levels anyone who thinks there is more pain in 2023 is insane. It's priced in and then some. This is not a structurally broken company.",
#   'like_num': 20,
#   'comment_num': 3,
#   'retweet_num': 0,
#   'tweet_activity': 23,
#   'clean_text': 'AMZN reverse prepandemic levels anyone thinks pain 2023 insane Its priced This structurally broken company',
#   'subjectivity': 1,
#   'sentiment': -1.0},
#  {'id': '1611520160719831040',
#   'company': 'amazon',
#   'post_date': '2023-01-07 00:28:41+00:00',
#   'author': 'Barchart',
#   'raw_text': '"I think that Amazon this year will report all-time record profits. I think in terms of quality and a management team that is absolutely as good as it gets" said legendary value investor Bill Miller who is doubling down on shares of $AMZN. https://t.co/Gg8dL9TdOW',
#   'like_num': 40,
#   'comment_num': 1,
#   'retweet_num': 5,
#   'tweet_activity': 46,
#   'clean_text': 'I think Amazon year report alltime record profits I think terms quality management team absolutely good gets said legendary value investor Bill Miller doubling shares AMZN',
#   'subjectivity': 0,
#   'sentiment': 0.5},
#  {'id': '1612221623557390336',
#   'company': 'amazon',
#   'post_date': '2023-01-08 22:56:03+00:00',
#   'author': 'WTIBull',
#   'raw_text': 'With $AMZN now pretty much defaulting back to 2-day and 3-day delivery (almost nothing is same day or next day and I live in Toronto), what’s the value proposition of using them?',
#   'like_num': 45,
#   'comment_num': 25,
#   'retweet_num': 0,
#   'tweet_activity': 70,
#   'clean_text': 'With AMZN pretty much defaulting back 2day 3day delivery almost nothing day next day I live Toronto whats value proposition using',
#   'subjectivity': 1,
#   'sentiment': 0.5},
#  ...]

# %%
# index data
print(solr.add(extracted_data))
# Out:
# {
#   "responseHeader":{
#     "status":0,
#     "QTime":1812}}

# %% [markdown]
# # Query guide
#
# Note that like_num, comment_num, retweet_num, tweet_activity, subjectivity, sentiment are not indexed and hence can't be queried. However, their values can be returned when relevant queries are made using other query fields such as id.

# %% [markdown]
# ## Single field query, query field = text body
#
# When querying the text body, query with clean_text, display raw_text

# %%
def display_results(search_results, query_field):
    # show spell correction only if query_field == "clean_text"
    if query_field == "clean_text":
        if len(search_results) == 0 and search_results.spellcheck['suggestions'][1]['numFound'] > 0:
            print("It seems the query you are searching if not present in the database. Here are some alternatives suggested queries: ")
            print(search_results.spellcheck['suggestions'][1]['suggestion'])
        else:
            for result in search_results:
                print("id: ", result["id"])
                print("company: ", result["company"])
                print("post_date: ", result["post_date"])
                print("author: ", result["author"])
                print("raw_text: ", result["raw_text"])
                print("like_num: ", result["like_num"])
                print("comment_num: ", result["comment_num"])
                print("retweet_num: ", result["retweet_num"])
                print("tweet_activity: ", result["tweet_activity"])
                print("subjectivity: ", result["subjectivity"])
                print("sentiment: ", result["sentiment"])
                print("====================================")
                print()
    else:
        if len(search_results) == 0:
            print("It seems the query you are searching if not present in the database")
        else:
            for result in search_results:
                print("id: ", result["id"])
                print("company: ", result["company"])
                print("post_date: ", result["post_date"])
                print("author: ", result["author"])
                print("raw_text: ", result["raw_text"])
                print("like_num: ", result["like_num"])
                print("comment_num: ", result["comment_num"])
                print("retweet_num: ", result["retweet_num"])
                print("tweet_activity: ", result["tweet_activity"])
                print("subjectivity: ", result["subjectivity"])
                print("sentiment: ", result["sentiment"])
                print("====================================")
                print()

# %%
# query on 1 field
query_field = "clean_text" # define the field to search under
query = "economically" # define the search term
fields_to_return = "id, company, post_date, author, raw_text, like_num, comment_num, retweet_num, tweet_activity, subjectivity, sentiment" # define the fields to return results
top_n_results = 3 # define the number of top results to return

query_string = "%s: %s" % (query_field, query)

search_results = solr.search(query_string, 
                             **{'fl': fields_to_return, 
                                'rows': top_n_results})

display_results(search_results, query_field)
# Out:
# id:  1610730772305936384
# company:  ['Microsoft']
# post_date:  2023-01-04T20:11:56Z
# author:  ['NestBetter']
# raw_text:  ['@LiebermanAustin C) there is no threat but $MSFT is about to force their hand and worsen the economics of search']
# like_num:  [19]
# comment_num:  [4]
# retweet_num:  [0]
# tweet_activity:  [23]
# subjectivity:  [1]
# sentiment:  [0]
# ====================================
#
# id:  1614029250730000384
# company:  ['Tesla']
# post_date:  2023-01-13T22:38:55Z
# author:  ['Teslaconomics']
# raw_text:  ['I believe 2M vehicles sold in 2023 is in the bag, barring any crazy economic event. $TSLA']
# like_num:  [493]
# comment_num:  [36]
# retweet_num:  [33]
# tweet_activity:  [562]
# subjectivity:  [1]
# sentiment:  [1]
# ====================================
#
# id:  1624473691408203776
# company:  ['apple']
# post_date:  2023-02-11T18:21:23Z
# author:  ['altcap']
# raw_text:  ['@tanayj Non consensus view.  Chat GPTs generally squeeze search economics which rolls downhill - less economics to google / msft search means less rev share to $aapl.  Further - Siri upgrades its own chat GPT capabilities intercepting many search queries.  Fewer ten blue links = less $$.']
# like_num:  [128]
# comment_num:  [6]
# retweet_num:  [5]
# tweet_activity:  [139]
# subjectivity:  [0]
# sentiment:  [0]
# ====================================

# %% [markdown]
# ## Single field query, query field = post date

# %%
# query on 1 field
query_field = "post_date" # define the field to search under
query = '[2023-01-01T23\:59\:59Z TO 2023-03-01T23\:59\:59Z]' # define the search term
fields_to_return = "id, company, post_date, author, raw_text, like_num, comment_num, retweet_num, tweet_activity, subjectivity, sentiment" # define the fields to return results
top_n_results = 3 # define the number of top results to return

query_string = "%s: %s" % (query_field, query)

search_results = solr.search(query_string, 
                             **{'fl': fields_to_return, 
                                'rows': top_n_results})

display_results(search_results, query_field)
# Out:
# id:  1610040852876857344
# company:  ['apple']
# post_date:  2023-01-02T22:30:27Z
# author:  ['korinek_trades']
# raw_text:  ['$AAPL has met my long term target \n\nSatisfying A=C and testing the long term TL support level\n\nThe sub waves are corrective and the triangle suggests that this has been a constructive retracement \n\nCircled area holds, 160–&gt;180+ can trade again IMO\n\nVery important spot here https://t.co/vSPR0thPEm']
# like_num:  [29]
# comment_num:  [1]
# retweet_num:  [8]
# tweet_activity:  [38]
# subjectivity:  [1]
# sentiment:  [1]
# ====================================
#
# id:  1610036971723948032
# company:  ['apple']
# post_date:  2023-01-02T22:15:01Z
# author:  ['BStew_ChArTs']
# raw_text:  ['$AAPL 🍎\n\nDaily and Weekly charts:\n\nWhat’s your thoughts? Bullish or Bearish?\n\nThere is a lot of support around this current area. \n\nIF AAPL breaks $105 area in 2023 there isn’t much support until around $82\n\nWill be Tech Giant maintain its #1 position? https://t.co/FOyLtSXxop']
# like_num:  [40]
# comment_num:  [6]
# retweet_num:  [6]
# tweet_activity:  [52]
# subjectivity:  [0]
# sentiment:  [0]
# ====================================
#
# id:  1610027687300718592
# company:  ['apple']
# post_date:  2023-01-02T21:38:08Z
# author:  ['JReam425']
# raw_text:  ["$AAPL Found some buyers off of $125. If you can't hold this level I am watching for move lower to $116, $107 https://t.co/QEGd9U1nxn"]
# like_num:  [22]
# comment_num:  [6]
# retweet_num:  [3]
# tweet_activity:  [31]
# subjectivity:  [0]
# sentiment:  [0]
# ====================================

# %% [markdown]
# # Single field query, query field = text body, query with wrong spelling
#
# Note that spell correction only applied to clean_text

# %%
# query on 1 field
query_field = "clean_text" # define the field to search under
query = 'increasy' # define the search term
fields_to_return = "id, company, post_date, author, raw_text, like_num, comment_num, retweet_num, tweet_activity, subjectivity, sentiment" # define the fields to return results
top_n_results = 3 # define the number of top results to return

query_string = "%s: %s" % (query_field, query)

search_results = solr.search(query_string, 
                             **{'fl': fields_to_return, 
                                'rows': top_n_results})

display_results(search_results, query_field)
# Out:
# It seems the query you are searching if not present in the database. Here are some alternatives suggested queries:
# ['increase', 'increased', 'increases']

# %% [markdown]
# # Multi-fields query

# %%
# query on multiple fields
fields_to_return = "id, company, post_date, author, raw_text, like_num, comment_num, retweet_num, tweet_activity, subjectivity, sentiment" # define the fields to return results
top_n_results = 3 # define the number of top results to return

query_string = "company: apple AND clean_text: increase" # AND OR

search_results = solr.search(query_string, 
                             **{'fl': fields_to_return, 
                                'rows': top_n_results})

display_results(search_results, query_field)
# Out:
# id:  1624062449799376896
# company:  ['apple']
# post_date:  2023-02-10T15:07:16Z
# author:  ['StockMKTNewz']
# raw_text:  ['Apple $AAPL grew its workforce by 20% between 2020 and 2022\n\nThat compares to a 50% increase at Microsoft, a 60% increase at Google and close to a 100% increase at Facebook, Amazon, and Salesforce - Bloomberg https://t.co/iCJ3slxMvJ']
# like_num:  [129]
# comment_num:  [5]
# retweet_num:  [22]
# tweet_activity:  [156]
# subjectivity:  [0]
# sentiment:  [0]
# ====================================
#
# id:  1626588479244345344
# company:  ['apple']
# post_date:  2023-02-17T14:24:48Z
# author:  ['DividendBreeder']
# raw_text:  ['Now that $O and $KO raised their dividend, here’s some more upcoming increase announcements I’m anticipating:\n\n$HD (Feb.)\n$AAPL (April)\n$JNJ (April)\n$PG (April)\n\nAnd maybe, just maybe, AT&amp;T $T will announce a small increase in March.']
# like_num:  [75]
# comment_num:  [7]
# retweet_num:  [4]
# tweet_activity:  [86]
# subjectivity:  [1]
# sentiment:  [1]
# ====================================
#
# id:  1625606452168757248
# company:  ['apple']
# post_date:  2023-02-14T21:22:35Z
# author:  ['unusual_whales']
# raw_text:  ['JUST IN: Warren Buffett’s Berkshire Hathaway increased its stake in Apple, $AAPL, by over $3 billion in the fourth quarter.']
# like_num:  [615]
# comment_num:  [29]
# retweet_num:  [74]
# tweet_activity:  [718]
# subjectivity:  [0]
# sentiment:  [0]
# ====================================
